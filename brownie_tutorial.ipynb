# %%
# Installing brownie
# !pip3 install eth-brownie
import brownie
# Out:
# Collecting eth-brownie
#   Using cached eth_brownie-1.19.5-py3-none-any.whl.metadata (9.9 kB)
# Collecting aiohttp==3.8.3 (from eth-brownie)
#   Using cached aiohttp-3.8.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting aiosignal==1.2.0 (from eth-brownie)
#   Using cached aiosignal-1.2.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting asttokens==2.0.5 (from eth-brownie)
#   Using cached asttokens-2.0.5-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting async-timeout==4.0.2 (from eth-brownie)
#   Using cached async_timeout-4.0.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting attrs==22.1.0 (from eth-brownie)
#   Using cached attrs-22.1.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting base58==2.1.1 (from eth-brownie)
#   Using cached base58-2.1.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting bitarray<3,>=2.6.0 (from eth-brownie)
#   Using cached bitarray-2.9.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting black==22.10.0 (from eth-brownie)
#   Using cached black-22.10.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (50 kB)
# Collecting certifi==2022.9.24 (from eth-brownie)
#   Using cached certifi-2022.9.24-py3-none-any.whl.metadata (2.9 kB)
# Collecting charset-normalizer==2.1.1 (from eth-brownie)
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting click==8.1.3 (from eth-brownie)
#   Using cached click-8.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting cytoolz==0.12.0 (from eth-brownie)
#   Using cached cytoolz-0.12.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.5 kB)
# Collecting dataclassy==0.11.1 (from eth-brownie)
#   Using cached dataclassy-0.11.1-py3-none-any.whl.metadata (22 kB)
# Collecting eip712==0.1.0 (from eth-brownie)
#   Using cached eip712-0.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting eth-abi==2.2.0 (from eth-brownie)
#   Using cached eth_abi-2.2.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting eth-account==0.5.9 (from eth-brownie)
#   Using cached eth_account-0.5.9-py3-none-any.whl.metadata (6.1 kB)
# Collecting eth-event==1.2.3 (from eth-brownie)
#   Using cached eth_event-1.2.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting eth-hash==0.3.3 (from eth-hash[pycryptodome]==0.3.3->eth-brownie)
#   Using cached eth_hash-0.3.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting eth-keyfile==0.5.1 (from eth-brownie)
#   Using cached eth_keyfile-0.5.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting eth-keys==0.3.4 (from eth-brownie)
#   Using cached eth_keys-0.3.4-py3-none-any.whl.metadata (12 kB)
# Collecting eth-rlp==0.2.1 (from eth-brownie)
#   Using cached eth_rlp-0.2.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting eth-typing==2.3.0 (from eth-brownie)
#   Using cached eth_typing-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting eth-utils==1.10.0 (from eth-brownie)
#   Using cached eth_utils-1.10.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting execnet==1.9.0 (from eth-brownie)
#   Using cached execnet-1.9.0-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting frozenlist==1.3.1 (from eth-brownie)
#   Using cached frozenlist-1.3.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.7 kB)
# Collecting hexbytes==0.2.3 (from eth-brownie)
#   Using cached hexbytes-0.2.3-py3-none-any.whl.metadata (6.6 kB)
# Collecting hypothesis==6.27.3 (from eth-brownie)
#   Using cached hypothesis-6.27.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting idna==3.4 (from eth-brownie)
#   Using cached idna-3.4-py3-none-any.whl.metadata (9.8 kB)
# Collecting inflection==0.5.0 (from eth-brownie)
#   Using cached inflection-0.5.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting iniconfig==1.1.1 (from eth-brownie)
#   Using cached iniconfig-1.1.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting ipfshttpclient==0.8.0a2 (from eth-brownie)
#   Using cached ipfshttpclient-0.8.0a2-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema==3.2.0 (from eth-brownie)
#   Using cached jsonschema-3.2.0-py2.py3-none-any.whl.metadata (7.8 kB)
# Collecting lazy-object-proxy==1.7.1 (from eth-brownie)
#   Using cached lazy-object-proxy-1.7.1.tar.gz (41 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lru-dict==1.1.8 (from eth-brownie)
#   Using cached lru-dict-1.1.8.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting multiaddr==0.0.9 (from eth-brownie)
#   Using cached multiaddr-0.0.9-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting multidict==6.0.2 (from eth-brownie)
#   Using cached multidict-6.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting mypy-extensions==0.4.3 (from eth-brownie)
#   Using cached mypy_extensions-0.4.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting mythx-models==1.9.1 (from eth-brownie)
#   Using cached mythx_models-1.9.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting netaddr==0.8.0 (from eth-brownie)
#   Using cached netaddr-0.8.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting packaging==21.3 (from eth-brownie)
#   Using cached packaging-21.3-py3-none-any.whl.metadata (15 kB)
# Collecting parsimonious==0.8.1 (from eth-brownie)
#   Using cached parsimonious-0.8.1.tar.gz (45 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pathspec==0.10.1 (from eth-brownie)
#   Using cached pathspec-0.10.1-py3-none-any.whl.metadata (16 kB)
# Collecting platformdirs==2.5.2 (from eth-brownie)
#   Using cached platformdirs-2.5.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting pluggy==1.0.0 (from eth-brownie)
#   Using cached pluggy-1.0.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting prompt-toolkit==3.0.31 (from eth-brownie)
#   Using cached prompt_toolkit-3.0.31-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf==3.19.5 (from eth-brownie)
#   Using cached protobuf-3.19.5-py2.py3-none-any.whl.metadata (828 bytes)
# Collecting psutil==5.9.2 (from eth-brownie)
#   Using cached psutil-5.9.2.tar.gz (479 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting py==1.11.0 (from eth-brownie)
#   Using cached py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting py-solc-ast==1.2.10 (from eth-brownie)
#   Using cached py_solc_ast-1.2.10-py3-none-any.whl.metadata (7.2 kB)
# Collecting py-solc-x==1.1.1 (from eth-brownie)
#   Using cached py_solc_x-1.1.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting pycryptodome==3.15.0 (from eth-brownie)
#   Using cached pycryptodome-3.15.0.tar.gz (4.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pygments==2.13.0 (from eth-brownie)
#   Using cached Pygments-2.13.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting pygments-lexer-solidity==0.7.0 (from eth-brownie)
#   Using cached pygments-lexer-solidity-0.7.0.tar.gz (7.3 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyjwt==1.7.1 (from eth-brownie)
#   Using cached PyJWT-1.7.1-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting pyparsing==3.0.9 (from eth-brownie)
#   Using cached pyparsing-3.0.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyrsistent==0.18.1 (from eth-brownie)
#   Using cached pyrsistent-0.18.1-cp39-cp39-macosx_10_9_universal2.whl.metadata (26 kB)
# Collecting pytest==6.2.5 (from eth-brownie)
#   Using cached pytest-6.2.5-py3-none-any.whl.metadata (7.5 kB)
# Collecting pytest-forked==1.4.0 (from eth-brownie)
#   Using cached pytest_forked-1.4.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pytest-xdist==1.34.0 (from eth-brownie)
#   Using cached pytest_xdist-1.34.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting python-dateutil==2.8.1 (from eth-brownie)
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting python-dotenv==0.16.0 (from eth-brownie)
#   Using cached python_dotenv-0.16.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting pythx==1.6.1 (from eth-brownie)
#   Using cached pythx-1.6.1-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting pyyaml==5.4.1 (from eth-brownie)
#   Using cached PyYAML-5.4.1.tar.gz (175 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [48 lines of output]
#       running egg_info
#       writing lib3/PyYAML.egg-info/PKG-INFO
#       writing dependency_links to lib3/PyYAML.egg-info/dependency_links.txt
#       writing top-level names to lib3/PyYAML.egg-info/top_level.txt
#       Traceback (most recent call last):
#         File "/Users/rushi/BlockChain/SmartContracts/.venv/lib/python3.9/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/rushi/BlockChain/SmartContracts/.venv/lib/python3.9/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Users/rushi/BlockChain/SmartContracts/.venv/lib/python3.9/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 271, in <module>
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 183, in setup
#           return run_commands(dist)
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 199, in run_commands
#           dist.run_commands()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 954, in run_commands
#           self.run_command(cmd)
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/dist.py", line 994, in run_command
#           super().run_command(command)
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 973, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/command/egg_info.py", line 312, in run
#           self.find_sources()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/command/egg_info.py", line 320, in find_sources
#           mm.run()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/command/egg_info.py", line 543, in run
#           self.add_defaults()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/command/egg_info.py", line 581, in add_defaults
#           sdist.add_defaults(self)
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/command/sdist.py", line 109, in add_defaults
#           super().add_defaults()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/sdist.py", line 238, in add_defaults
#           self._add_defaults_ext()
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/sdist.py", line 323, in _add_defaults_ext
#           self.filelist.extend(build_ext.get_source_files())
#         File "<string>", line 201, in get_source_files
#         File "/private/var/folders/45/c099d4kx4yjftz39dtrbqkdh0000gn/T/pip-build-env-9xsfxw9_/overlay/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 107, in __getattr__
#           raise AttributeError(attr)
#       AttributeError: cython_sources
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Installing brownie
#       2 get_ipython().system('pip3 install eth-brownie')
# ----> 3 import brownie
#
# ModuleNotFoundError: No module named 'brownie'

# %%
# Install ganache as brownie is dependent on it. And to install ganache, you need to install javascript library node.js(npm- node package manager)
# Ganache cli will help us while testing the smart contract once developed. Test network access from python IDE via cli
# Npm has been installed from node.js website as a prebuild package.But run the following command in terminal to deal with the permission issue
#!sudo chown -R 501:20 ~/.npm

# %%
# !npm install -g ganache
# Now you can run a ethereum chain locally
# Out:
# npm WARN In ganache@7.9.2 replacing bundled version of minimalistic-assert with minimalistic-assert@1.0.1
# npm WARN In ganache@7.9.2 replacing bundled version of is-buffer with is-buffer@2.0.5
# npm WARN In ganache@7.9.2 replacing bundled version of inherits with inherits@2.0.4
# npm WARN In ganache@7.9.2 replacing bundled version of queue-microtask with queue-microtask@1.2.3
# npm WARN In ganache@7.9.2 replacing bundled version of brorand with brorand@1.1.0
# npm WARN In ganache@7.9.2 replacing bundled version of ieee754 with ieee754@1.2.1
# npm WARN In ganache@7.9.2 replacing bundled version of string_decoder with string_decoder@1.3.0
# npm WARN In ganache@7.9.2 replacing bundled version of level-concat-iterator with level-concat-iterator@3.1.0
# npm WARN In ganache@7.9.2 replacing bundled version of base64-js with base64-js@1.5.1
# npm WARN In ganache@7.9.2 replacing bundled version of catering with catering@2.1.1
# npm WARN In ganache@7.9.2 replacing bundled version of minimalistic-crypto-utils with minimalistic-crypto-utils@1.0.1
# npm WARN In ganache@7.9.2 replacing bundled version of util-deprecate with util-deprecate@1.0.2
# npm WARN In ganache@7.9.2 replacing bundled version of safe-buffer with safe-buffer@5.2.1
# npm WARN In ganache@7.9.2 replacing bundled version of hmac-drbg with hmac-drbg@1.0.1
# npm WARN In ganache@7.9.2 replacing bundled version of node-gyp-build with node-gyp-build@4.5.0
# npm WARN In ganache@7.9.2 replacing bundled version of napi-macros with napi-macros@2.0.0
# npm WARN In ganache@7.9.2 replacing bundled version of level-supports with level-supports@2.1.0
# npm WARN In ganache@7.9.2 replacing bundled version of buffer with buffer@6.0.3
# npm WARN In ganache@7.9.2 replacing bundled version of bn.js with bn.js@4.12.0
# npm WARN In ganache@7.9.2 replacing bundled version of hash.js with hash.js@1.1.7
# npm WARN In ganache@7.9.2 replacing bundled version of readable-stream with readable-stream@3.6.0
# npm WARN In ganache@7.9.2 replacing bundled version of abstract-leveldown with abstract-leveldown@7.2.0
# npm WARN In ganache@7.9.2 replacing bundled version of node-gyp-build with node-gyp-build@4.4.0
# npm WARN In ganache@7.9.2 replacing bundled version of keccak with keccak@3.0.2
# npm WARN In ganache@7.9.2 replacing bundled version of node-addon-api with node-addon-api@2.0.2
# npm WARN In ganache@7.9.2 replacing bundled version of secp256k1 with secp256k1@4.0.3
# npm WARN In ganache@7.9.2 replacing bundled version of leveldown with leveldown@6.1.0
# npm WARN In ganache@7.9.2 replacing bundled version of @trufflesuite/bigint-buffer with @trufflesuite/bigint-buffer@1.1.10
# npm WARN In ganache@7.9.2 replacing bundled version of elliptic with elliptic@6.5.4
# npm ERR! Darwin 23.5.0
# npm ERR! argv "/usr/local/bin/node" "/usr/local/bin/npm" "install" "-g" "ganache"
# npm ERR! node v6.17.1
# npm ERR! npm  v3.10.10
# npm ERR! path ../lib/node_modules/ganache/dist/node/cli.js
# npm ERR! code EACCES
# npm ERR! errno -13
# npm ERR! syscall symlink
#
# npm ERR! Error: EACCES: permission denied, symlink '../lib/node_modules/ganache/dist/node/cli.js' -> '/usr/local/bin/ganache-cli'
# npm ERR!     at Error (native)
# npm ERR!  { Error: EACCES: permission denied, symlink '../lib/node_modules/ganache/dist/node/cli.js' -> '/usr/local/bin/ganache-cli'
# npm ERR!     at Error (native)
# npm ERR!   errno: -13,
# npm ERR!   code: 'EACCES',
# npm ERR!   syscall: 'symlink',
# npm ERR!   path: '../lib/node_modules/ganache/dist/node/cli.js',
# npm ERR!   dest: '/usr/local/bin/ganache-cli' }
# npm ERR!
# npm ERR! Please try running this command again as root/Administrator.
#
# npm ERR! Please include the following file with any support request:
# npm ERR!     /Users/rushi/Desktop/BlockChain/General/SmartContracts/npm-debug.log

# %%
# Importing the chainlink-mix to brownie to interact with the project using predeveloped library
# !brownie bake chainlink-mix
# Out:
# zsh:1: command not found: brownie

# %%
import time

def random_number_gen(min_range, max_range):
    current_time = int(time.time() * 1e6)
    pri
    random_number = (current_time % (max_range + 1 - min_range)) + min_range
    return random_number

# %%
random_number_gen(5,10)
# Out:
# 8

# %%
current_time = int(time.time() * 1e6)
random_number = (current_time % (10 + 1 - 5)) + 5

random_number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 current_time = int(time.time() * 1e6)
# ----> 2 random_number = (current_time % (max_range + 1 - min_range)) + min_range
#       4 random_number
#
# NameError: name 'max_range' is not defined
